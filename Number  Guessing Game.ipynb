# %%
#Opening statement

print("Welcome to the number guessing game. Think of a number between 0 and 100. After I guess, respond with 'too low', 'too high', or 'correct' ")

#variables

upper = 101

lower = 0

middle = 50

tries = 1

#main

while upper > lower: 
    if tries < 8: 
        play_game = input('Are you ready to play? Enter Yes or No.')
        
        if play_game.lower()[0] == 'y':
            game_on = True
        else:
            game_on = False
            break
        while game_on:
        
            print(middle)
            response = input()
            if response == "correct":
                print("I win!")  
                break 
            if response == "too high":
                upper = middle 
                middle = (upper + lower) //2
            if response == "too low":
                lower = middle 
                middle = (upper + lower) //2     
            tries += 1
# Out:
# Welcome to the number guessing game. Think of a number between 0 and 100. After I guess, respond with 'too low', 'too high', or 'correct'

# %%
def is_nugget_number(candidate, SIX = 6, NINE = 9, TWENTY = 20):
    for i in range(candidate//SIX + 1):
        for j in range(candidate//NINE + 1):
            for k in range(candidate//TWENTY + 1):
                if(candidate == i * SIX + j * NINE + k * TWENTY):
                    return True
    return False
   
    
    
## main
SIX = 6
count = 0
largest = 0
candidate = 6

while count < SIX: 
    if(is_nugget_number(candidate)):
        count += 1        
    else:
        largest = candidate
        count = 0
    candidate += 1
        
print("THe largest size tha tyou cannot get is: {0}".format(largest))









def is_nugget_number(candidate,packets):
    s = packets['s']
    m = packets['m']
    l = pacekts['l']
    
    for i in range(candidate//s + 1)
        for j in range(candidate//m + 1)
            for k in range(candidate //l + 1):
                return True
          
    return False    
    
    
## Main
packets = {'s' : 6, 'm' : 9, 'l' : 20}


# Is a given number a nugget number
Candidate = ['s']

# Keep track of how many Candidates in a row are nugget numbers

count = 0

# What is the most recent candidate that was not a number
largest = 0

#Loop until stopping rule ment
while count < packets['s']:
    if is_nugget_number(candidate):
        count += 1
    else:
        count = 0
        largest = candidate
        
    candidate += 1

print(f"The largest number of nuggets that i cannot get is: {largest}")
